# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_clean_df = application_df.drop(["EIN", "NAME"], axis=1)
application_clean_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
dataframe_count = application_clean_df.dtypes.index.tolist()
application_clean_df[dataframe_count].nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
df_types_count = application_clean_df['APPLICATION_TYPE'].value_counts()
df_types_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(df_types_count[df_types_count < 650].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = application_clean_df['CLASSIFICATION'].value_counts()
class_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_clean_df["CLASSIFICATION"].value_counts().loc[lambda x : x >1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_count[class_count < 300].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies = pd.get_dummies(application_clean_df)
dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  APPLICATION_TYPE_T15  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  INCOME_AMT_1-9999  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = dummies["IS_SUCCESSFUL"].values
X = dummies.drop("IS_SUCCESSFUL", axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %% [markdown]
# **Test #1**

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30


nn_1 = tf.keras.models.Sequential()

# First hidden layer
nn_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer1,
             input_dim=input_features, activation="relu"))

# Second hidden layer
nn_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer2,
             input_dim=input_features, activation="relu"))

# Output layer
nn_1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                9360
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# ...
# Total params: 11821 (46.18 KB)
# Trainable params: 11821 (46.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn_1.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5736 - accuracy: 0.7239
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5527 - accuracy: 0.7314
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5490 - accuracy: 0.7338
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5466 - accuracy: 0.7338
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5455 - accuracy: 0.7343
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5442 - accuracy: 0.7346
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5438 - accuracy: 0.7357
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7364
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5421 - accuracy: 0.7358
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5646 - accuracy: 0.7261 - 469ms/epoch - 2ms/step
# Loss: 0.5646114349365234, Accuracy: 0.726064145565033

# %%
# Export our model to HDF5 file
from google.colab import files

nn_1.save('AlphabetSoupCharity_Optimization_test1.h5')
files.download('AlphabetSoupCharity_Optimization_test1.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# **Test #2 - increase nodes in both layers**

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 200
hidden_nodes_layer2 = 100


nn_2 = tf.keras.models.Sequential()

# First hidden layer
nn_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer1,
             input_dim=input_features, activation="relu"))

# Second hidden layer
nn_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2,
             input_dim=input_features, activation="relu"))

# Output layer
nn_2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 200)               23400
#
#  dense_4 (Dense)             (None, 100)               20100
#
#  dense_5 (Dense)             (None, 1)                 101
#
# ...
# Total params: 43601 (170.32 KB)
# Trainable params: 43601 (170.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn_2.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5728 - accuracy: 0.7235
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5532 - accuracy: 0.7309
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7318
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5464 - accuracy: 0.7350
# Epoch 5/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5451 - accuracy: 0.7355
# Epoch 6/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5441 - accuracy: 0.7357
# Epoch 7/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5432 - accuracy: 0.7353
# Epoch 8/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5425 - accuracy: 0.7366
# Epoch 9/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5421 - accuracy: 0.7367
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6277 - accuracy: 0.7257 - 455ms/epoch - 2ms/step
# Loss: 0.6276857256889343, Accuracy: 0.7257142663002014

# %%
# Export our model to HDF5 file
nn_2.save('AlphabetSoupCharity_Optimization_test2.h5')
files.download('AlphabetSoupCharity_Optimization_test2.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# **Test #3 - increase epochs**

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 200
hidden_nodes_layer2 = 100


nn_3 = tf.keras.models.Sequential()

# First hidden layer
nn_3.add(tf.keras.layers.Dense(units=hidden_nodes_layer1,
             input_dim=input_features, activation="relu"))

# Second hidden layer
nn_3.add(tf.keras.layers.Dense(units=hidden_nodes_layer2,
             input_dim=input_features, activation="relu"))

# Output layer
nn_3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 200)               23400
#
#  dense_7 (Dense)             (None, 100)               20100
#
#  dense_8 (Dense)             (None, 1)                 101
#
# ...
# Total params: 43601 (170.32 KB)
# Trainable params: 43601 (170.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn_3.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5727 - accuracy: 0.7252
# Epoch 2/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5520 - accuracy: 0.7311
# Epoch 3/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7342
# Epoch 4/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5464 - accuracy: 0.7343
# Epoch 5/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5452 - accuracy: 0.7336
# Epoch 6/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5440 - accuracy: 0.7364
# Epoch 7/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5430 - accuracy: 0.7355
# Epoch 8/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5427 - accuracy: 0.7365
# Epoch 9/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7379
# Epoch 10/200
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.9926 - accuracy: 0.7263 - 446ms/epoch - 2ms/step
# Loss: 0.9926190972328186, Accuracy: 0.7262973785400391

# %%
# Export our model to HDF5 file
nn_3.save('AlphabetSoupCharity_Optimization_test3.h5')
files.download('AlphabetSoupCharity_Optimization_test3.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# **Test #4 - add layer**

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 200
hidden_nodes_layer2 = 100
hidden_nodes_layer3 = 100


nn_4 = tf.keras.models.Sequential()

# First hidden layer
nn_4.add(tf.keras.layers.Dense(units=hidden_nodes_layer1,
             input_dim=input_features, activation="relu"))

# Second hidden layer
nn_4.add(tf.keras.layers.Dense(units=hidden_nodes_layer2,
             input_dim=input_features, activation="relu"))

# Third hidden layer
nn_4.add(tf.keras.layers.Dense(units=hidden_nodes_layer3,
             input_dim=input_features, activation="relu"))

# Output layer
nn_4.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 200)               23400
#
#  dense_10 (Dense)            (None, 100)               20100
#
#  dense_11 (Dense)            (None, 100)               10100
#
#  dense_12 (Dense)            (None, 1)                 101
#
# ...
# Total params: 53701 (209.77 KB)
# Trainable params: 53701 (209.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_4.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn_4.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5691 - accuracy: 0.7252
# Epoch 2/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5530 - accuracy: 0.7327
# Epoch 3/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5494 - accuracy: 0.7339
# Epoch 4/200
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5458 - accuracy: 0.7349
# Epoch 5/200
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5455 - accuracy: 0.7342
# Epoch 6/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5444 - accuracy: 0.7364
# Epoch 7/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5437 - accuracy: 0.7364
# Epoch 8/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7367
# Epoch 9/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7366
# Epoch 10/200
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_4.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.7831 - accuracy: 0.7279 - 466ms/epoch - 2ms/step
# Loss: 0.7831496000289917, Accuracy: 0.7279300093650818

# %%
# Export our model to HDF5 file
nn_4.save('AlphabetSoupCharity_Optimization_test4.h5')
files.download('AlphabetSoupCharity_Optimization_test4.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# **Test #5 - add batches and batch normalization**

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 200
hidden_nodes_layer2 = 100


nn_5 = tf.keras.models.Sequential()

# First hidden layer
nn_5.add(tf.keras.layers.Dense(units=hidden_nodes_layer1,
             input_dim=input_features, activation="relu"))
nn_5.add(tf.keras.layers.BatchNormalization())

# Second hidden layer
nn_5.add(tf.keras.layers.Dense(units=hidden_nodes_layer2,
             input_dim=input_features, activation="relu"))
nn_5.add(tf.keras.layers.BatchNormalization())

# Output layer
nn_5.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_13 (Dense)            (None, 200)               23400
#
#  batch_normalization (Batch  (None, 200)               800
#  Normalization)
#
#  dense_14 (Dense)            (None, 100)               20100
#
#  batch_normalization_1 (Bat  (None, 100)               400
#  chNormalization)
#
#  dense_15 (Dense)            (None, 1)                 101
#
# ...
# Total params: 44801 (175.00 KB)
# Trainable params: 44201 (172.66 KB)
# Non-trainable params: 600 (2.34 KB)
# _________________________________________________________________

# %%
# Compile the model
nn_5.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn_5.fit(X_train_scaled, y_train, epochs=100,batch_size=50)
# Out:
# Epoch 1/100
# 515/515 [==============================] - 3s 3ms/step - loss: 0.5909 - accuracy: 0.7130
# Epoch 2/100
# 515/515 [==============================] - 1s 3ms/step - loss: 0.5607 - accuracy: 0.7269
# Epoch 3/100
# 515/515 [==============================] - 2s 3ms/step - loss: 0.5572 - accuracy: 0.7284
# Epoch 4/100
# 515/515 [==============================] - 2s 5ms/step - loss: 0.5541 - accuracy: 0.7314
# Epoch 5/100
# 515/515 [==============================] - 3s 5ms/step - loss: 0.5527 - accuracy: 0.7306
# Epoch 6/100
# 515/515 [==============================] - 2s 3ms/step - loss: 0.5513 - accuracy: 0.7306
# Epoch 7/100
# 515/515 [==============================] - 2s 3ms/step - loss: 0.5507 - accuracy: 0.7310
# Epoch 8/100
# 515/515 [==============================] - 2s 3ms/step - loss: 0.5491 - accuracy: 0.7322
# Epoch 9/100
# 515/515 [==============================] - 2s 4ms/step - loss: 0.5491 - accuracy: 0.7327
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_5.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5567 - accuracy: 0.7278 - 515ms/epoch - 2ms/step
# Loss: 0.5566544532775879, Accuracy: 0.7278134226799011

# %%
# Export our model to HDF5 file
nn_5.save('AlphabetSoupCharity_Optimization_test5.h5')
files.download('AlphabetSoupCharity_Optimization_test5.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
